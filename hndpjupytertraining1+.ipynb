# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#2019
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Des']
sales019 = [1350039, 5295835, 3583583, 8853284, 7385243, 8247357, 2384583, 6863358, 10274375, 7357281, 8321853,
            9274863]
sales2019 = ['  $1.350.039', '  $5.295.835', '  $3.583.583', '  $8.853.284', '  $7.385.243', '  $8.247.357',
             '  $2.384.583', '  $6.863.358', '  $10.274.375', '  $7.357.281', '  $8.321.853', '  $9.274.863']

plt.figure(figsize=(25, 10))
plt.plot(months, sales019, label='2019', marker='.', markeredgecolor='red', markersize='20' )
plt.title('hndp industry', {'fontsize': 30})
plt.ticklabel_format(style='plain', axis='y')

plt.text(months[0], sales019[0], sales2019[0])
plt.text(months[1], sales019[1], sales2019[1])
plt.text(months[2], sales019[2], sales2019[2])
plt.text(months[3], sales019[3], sales2019[3])
plt.text(months[4], sales019[4], sales2019[4])
plt.text(months[5], sales019[5], sales2019[5])
plt.text(months[6], sales019[6], sales2019[6])
plt.text(months[7], sales019[7], sales2019[7])
plt.text(months[8], sales019[8], sales2019[8])
plt.text(months[9], sales019[9], sales2019[9])
plt.text(months[10], sales019[10], sales2019[10])
plt.text(months[11], sales019[11], sales2019[11])

plt.legend()
plt.show()
# Out:
#   File "<ipython-input-42-8687c66aa53c>", line 29
#     print(months[0] = 'sales020', -, 'sales019'
#                                    ^
# SyntaxError: invalid syntax

# %%
#2020
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Des']
sales020 = [3520439, 4235835, 7583583, 8863484, 5685543, 2347657, 3784283, 4663558, 6674575, 7757781, 9731553, 
            7874463]
sales2020 = ['  $3.520.439', '  $4.235.835', '  $7.583.583', '  $8.863.484', '  $5.685.543', '  $2.347.657', 
             '  $3.784.283', '  $4.663.558', '  $6.674.575', '  $7.757.781', '  $9.731.553', '  $7.874.463']

plt.figure(figsize=(25, 10))
plt.plot(months, sales020, label='2020', marker='.', markeredgecolor='red', markersize='20')
plt.title('hndp industry', {'fontsize': 30})
plt.ticklabel_format(style='plain', axis='y')

plt.text(months[0], sales020[0], sales2020[0])
plt.text(months[1], sales020[1], sales2020[1])
plt.text(months[2], sales020[2], sales2019[2])
plt.text(months[3], sales020[3], sales2020[3])
plt.text(months[4], sales020[4], sales2020[4])
plt.text(months[5], sales020[5], sales2020[5])
plt.text(months[6], sales020[6], sales2020[6])
plt.text(months[7], sales020[7], sales2020[7])
plt.text(months[8], sales020[8], sales2020[8])
plt.text(months[9], sales020[9], sales2020[9])
plt.text(months[10], sales020[10], sales2020[10])
plt.text(months[11], sales020[11], sales2020[11])

plt.legend()
plt.show()

# %%
#2019 - 2020
#2020
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Des']
sales020 = [3520439, 4235835, 7583583, 8863484, 5685543, 2347657, 3784283, 4663558, 6674575, 7757781, 9731553, 
                    7874463]
sales2020 = ['  $3.520.439', '  $4.235.835', '  $7.583.583', '  $8.863.484', '  $5.685.543', '  $2.347.657', 
             '  $3.784.283', '  $4.663.558', '  $6.674.575', '  $7.757.781', '  $9.731.553', '  $7.874.463']

sales019 = [1350039, 5295835, 3583583, 8853284, 7385243, 8247357, 2384583, 6863358, 10274375, 7357281, 8321853, 
         9274863]
sales2019 = ['  $1.350.039', '  $5.295.835', '  $3.583.583', '  $8.853.284', '  $7.385.243', '  $8.247.357', 
             '  $2.384.583', '  $6.863.358', '  $10.274.375', '  $7.357.281', '  $8.321.853', '  $9.274.863']

plt.figure(figsize=(25, 10))
plt.plot(months, sales020, label='2020', marker='.', markeredgecolor='red', markersize='20')
plt.plot(months, sales019, label='2019', marker='.', markeredgecolor='red', markersize='20')
plt.title('hndp industry', {'fontsize': 30})
plt.ticklabel_format(style='plain', axis='y')

plt.text(months020[0], sales020[0], sales2020[0])
plt.text(months020[1], sales020[1], sales2020[1])
plt.text(months020[2], sales020[2], sales2019[2])
plt.text(months020[3], sales020[3], sales2020[3])
plt.text(months020[4], sales020[4], sales2020[4])
plt.text(months020[5], sales020[5], sales2020[5])
plt.text(months020[6], sales020[6], sales2020[6])
plt.text(months020[7], sales020[7], sales2020[7])
plt.text(months020[8], sales020[8], sales2020[8])
plt.text(months020[9], sales020[9], sales2020[9])
plt.text(months020[10], sales020[10], sales2020[10])
plt.text(months020[11], sales020[11], sales2020[11])

plt.text(months[0], sales019[0], sales2019[0])
plt.text(months[1], sales019[1], sales2019[1])
plt.text(months[2], sales019[2], sales2019[2])
plt.text(months[3], sales019[3], sales2019[3])
plt.text(months[4], sales019[4], sales2019[4])
plt.text(months[5], sales019[5], sales2019[5])
plt.text(months[6], sales019[6], sales2019[6])
plt.text(months[7], sales019[7], sales2019[7])
plt.text(months[8], sales019[8], sales2019[8])
plt.text(months[9], sales019[9], sales2019[9])
plt.text(months[10], sales019[10], sales2019[10])
plt.text(months[11], sales019[11], sales2019[11])

plt.legend()
plt.show()

print("2020 sales compared to 2019 sales :")
print("")

print(months[0], "=", "$", sales020[0] - sales019[0])
print(months[1], "=", "$", sales020[1] - sales019[1])
print(months[2], "=", "$", sales020[2] - sales019[2])
print(months[3], "=", "$", sales020[3] - sales019[3])
print(months[4], "=", "$", sales020[4] - sales019[4])
print(months[5], "=", "$", sales020[5] - sales019[5])
print(months[6], "=", "$", sales020[6] - sales019[6])
print(months[7], "=", "$", sales020[7] - sales019[7])
print(months[8], "=", "$", sales020[8] - sales019[8])
print(months[9], "=", "$", sales020[9] - sales019[9])
print(months[10], "=", "$", sales020[10] - sales019[10])
print(months[11], "=", "$", sales020[11] - sales019[11])

print("Total = ", "$", sum(sales020) - sum(sales019))
# Out:
# 2020 sales compared to 2019 sales :
#
# Jan = $ 2170400
# Feb = $ -1060000
# Mar = $ 4000000
# Apr = $ 10200
# May = $ -1699700
# Jun = $ -5899700
# Jul = $ 1399700
# Aug = $ -2199800
# Sep = $ -3599800
# Oct = $ 400500
# Nov = $ 1409700
# Des = $ -1400400
# Total =  $ -6468900
